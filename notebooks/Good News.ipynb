# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import requests

# %%
r = requests.get('https://api.globalhealth5050.org/api/v1/summary')

j = r.json()
# Out:
# {'country': 'Argentina',
#  'country_code': 'AR',
#  'date': '6/15/2021',
#  'sexdisagg_data': 'Yes',
#  'date_tests': '',
#  'tests_date': '',
#  'tests_male': '',
#  'tests_female': '',
#  'tests_male_pct': '',
#  'tests_female_pct': '',
#  'date_cases': '6/14/21',
#  'cases_date': '6/14/21',
#  'cases_total': '4111147',
#  'cases_total_sum': '4107009',
#  'cases_male': '2039047',
#  'cases_female': '2067962',
#  'cases_male_pct': '0.49648',
#  'cases_female_pct': '0.503520',
#  'date_deaths': '6/14/21',
#  'deaths_date': '6/14/21',
#  'deaths_total': '85075',
#  'deaths_total_sum': '83855',
#  'deaths_male': '48743',
#  'deaths_female': '35112',
#  'deaths_male_pct': '0.58128',
#  'deaths_female_pct': '0.418723',
#  'hosp_date': '',
#  'hosp_total': '',
#  'hosp_male': '',
#  'hosp_female': '',
#  'hosp_male_pct': '',
#  'hosp_female_pct': '',
#  'icu_date': '',
#  'icu_total': '',
#  'icu_male': '',
#  'icu_female': '',
#  'icu_male_pct': '',
#  'icu_female_pct': '',
# ...

# %%
j['data']['Denmark']
# Out:
# {'country': 'Denmark',
#  'country_code': 'DK',
#  'date': '6/15/21',
#  'sexdisagg_data': 'Yes',
#  'date_tests': '6/15/21',
#  'tests_date': '6/15/21',
#  'tests_male': '2394065',
#  'tests_female': '2500487',
#  'tests_male_pct': '0.489129',
#  'tests_female_pct': '0.510871',
#  'date_cases': '6/15/21',
#  'cases_date': '6/15/21',
#  'cases_total': '290111',
#  'cases_total_sum': '290333',
#  'cases_male': '144458',
#  'cases_female': '145875',
#  'cases_male_pct': '0.49756',
#  'cases_female_pct': '0.50244',
#  'date_deaths': '6/15/21',
#  'deaths_date': '6/15/21',
#  'deaths_total': '2526',
#  'deaths_total_sum': '2527',
#  'deaths_male': '1374',
#  'deaths_female': '1153',
#  'deaths_male_pct': '0.543728',
#  'deaths_female_pct': '0.456272',
#  'hosp_date': '6/15/21',
#  'hosp_total': '15567',
#  'hosp_male': '8198',
#  'hosp_female': '7369',
#  'hosp_male_pct': '0.526627',
#  'hosp_female_pct': '0.473373',
#  'icu_date': '6/15/21',
#  'icu_total': '1749',
# ...

# %%
r = requests.get('https://newsdata.io/api/1/news?apikey=pub_48323a34fefa3b526c810996a514b8f44c2&country=in&category=health&q=coronavirus%20OR%20covid')

j = r.json()

j
# Out:
# {'status': 'success',
#  'totalResults': 71,
#  'results': [{'title': "Pics of people thronging hill stations 'frightening', govt stresses on COVID protocols",
#    'link': 'https://www.thenewsminute.com/article/pics-people-thronging-hill-stations-frightening-govt-stresses-covid-protocols-151850',
#    'keywords': None,
#    'creator': ['AjayR'],
#    'video_url': None,
# ...
